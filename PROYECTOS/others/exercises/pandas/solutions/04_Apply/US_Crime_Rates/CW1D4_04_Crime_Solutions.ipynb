# %% [markdown]
# # United States - Crime Rates - 1960 - 2014

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv).

# %% [markdown]
# ### Step 3. Assign it to a variable called crime.

# %%
url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/04_Apply/US_Crime_Rates/US_Crime_Rates_1960_2014.csv"
crime = pd.read_csv(url, parse_dates=["Year"], infer_datetime_format="%Y")
crime.head()
# Out:
#         Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 2 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 3 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 4 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %% [markdown]
# ### Step 4. What is the type of the columns?

# %%
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     datetime64[ns]
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: datetime64[ns](1), int64(11)
# memory usage: 5.2 KB

# %% [markdown]
# ##### Have you noticed that the type of Year is int64. But pandas has a different type to work with Time Series. Let's see it now.
#
# ### Step 5. Convert the type of the column Year to datetime64

# %%
crime1 = pd.to_datetime(crime.Year)
crime1
# Out:
# 0    1960-01-01
# 1    1961-01-01
# 2    1962-01-01
# 3    1963-01-01
# 4    1964-01-01
# 5    1965-01-01
# 6    1966-01-01
# 7    1967-01-01
# 8    1968-01-01
# 9    1969-01-01
# 10   1970-01-01
# 11   1971-01-01
# 12   1972-01-01
# 13   1973-01-01
# 14   1974-01-01
# 15   1975-01-01
# 16   1976-01-01
# 17   1977-01-01
# 18   1978-01-01
# 19   1979-01-01
# 20   1980-01-01
# 21   1981-01-01
# 22   1982-01-01
# 23   1983-01-01
# 24   1984-01-01
# 25   1985-01-01
# 26   1986-01-01
# 27   1987-01-01
# 28   1988-01-01
# 29   1989-01-01
# 30   1990-01-01
# 31   1991-01-01
# 32   1992-01-01
# 33   1993-01-01
# 34   1994-01-01
# 35   1995-01-01
# 36   1996-01-01
# 37   1997-01-01
# 38   1998-01-01
# 39   1999-01-01
# 40   2000-01-01
# 41   2001-01-01
# 42   2002-01-01
# 43   2003-01-01
# 44   2004-01-01
# 45   2005-01-01
# 46   2006-01-01
# 47   2007-01-01
# 48   2008-01-01
# 49   2009-01-01
# 50   2010-01-01
# 51   2011-01-01
# 52   2012-01-01
# 53   2013-01-01
# 54   2014-01-01
# Name: Year, dtype: datetime64[ns]

# %%
# pd.to_datetime(crime)
crime.Year = pd.to_datetime(crime.Year, format='%Y')
crime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     datetime64[ns]
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: datetime64[ns](1), int64(11)
# memory usage: 5.2 KB

# %%
crime.head()
# Out:
#         Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 2 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 3 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 4 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %% [markdown]
# ### Step 6. Set the Year column as the index of the dataframe

# %%
crime.set_index('Year', inplace=True)
crime.head()
# Out:
#             Population    Total  Violent  Property  Murder  Forcible_Rape  \
# Year
# 1960-01-01   179323175  3384200   288460   3095700    9110          17190
# 1961-01-01   182992000  3488000   289390   3198600    8740          17220
# 1962-01-01   185771000  3752200   301510   3450700    8530          17550
# 1963-01-01   188483000  4109500   316970   3792500    8640          17650
# 1964-01-01   191141000  4564600   364220   4200400    9360          21420
#
#             Robbery  Aggravated_assault  Burglary  Larceny_Theft  \
# Year
# 1960-01-01   107840              154320    912100        1855400
# 1961-01-01   106670              156760    949600        1913000
# 1962-01-01   110860              164570    994300        2089600
# 1963-01-01   116470              174210   1086400        2297800
# 1964-01-01   130390              203050   1213200        2514400
#
#             Vehicle_Theft
# Year
# 1960-01-01         328200
# 1961-01-01         336000
# 1962-01-01         366800
# 1963-01-01         408300
# 1964-01-01         472800

# %%
crime.reset_index(drop=True, inplace=True)

# %%
crime.head()
# Out:
#    Population    Total  Violent  Property  Murder  Forcible_Rape  Robbery  \
# 0   179323175  3384200   288460   3095700    9110          17190   107840
# 1   182992000  3488000   289390   3198600    8740          17220   106670
# 2   185771000  3752200   301510   3450700    8530          17550   110860
# 3   188483000  4109500   316970   3792500    8640          17650   116470
# 4   191141000  4564600   364220   4200400    9360          21420   130390
#
#    Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0              154320    912100        1855400         328200
# 1              156760    949600        1913000         336000
# 2              164570    994300        2089600         366800
# 3              174210   1086400        2297800         408300
# 4              203050   1213200        2514400         472800

# %%
del crime["index"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-11-03baf1d5e748> in <module>
# ----> 1 del crime["index"]
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\generic.py in __delitem__(self, key)
#    3757             # there was no match, this call should raise the appropriate
#    3758             # exception:
# -> 3759             self._data.delete(key)
#    3760
#    3761         # delete from the caches
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\internals\managers.py in delete(self, item)
#    1000         Delete selected item (items if non-unique) in-place.
#    1001         """
# -> 1002         indexer = self.items.get_loc(item)
#    1003
#    1004         is_deleted = np.zeros(self.shape[0], dtype=np.bool_)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# -> 2648                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2649         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2650         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'index'

# %%
crime.head()
# Out:
#    Population    Total  Violent  Property  Murder  Forcible_Rape  Robbery  \
# 0   179323175  3384200   288460   3095700    9110          17190   107840
# 1   182992000  3488000   289390   3198600    8740          17220   106670
# 2   185771000  3752200   301510   3450700    8530          17550   110860
# 3   188483000  4109500   316970   3792500    8640          17650   116470
# 4   191141000  4564600   364220   4200400    9360          21420   130390
#
#    Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0              154320    912100        1855400         328200
# 1              156760    949600        1913000         336000
# 2              164570    994300        2089600         366800
# 3              174210   1086400        2297800         408300
# 4              203050   1213200        2514400         472800

# %%
crime = crime.set_index('Year', drop=True)
crime.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-3edad849de1a> in <module>
# ----> 1 crime = crime.set_index('Year', drop=True)
#       2 crime.head()
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Year'] are in the columns"

# %%
crime.Population.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Step 7. Delete the Total column

# %%
crime.drop(columns=["Total"], axis=1)
# Out:
#     Population  Violent  Property  Murder  Forcible_Rape  Robbery  \
# 0    179323175   288460   3095700    9110          17190   107840
# 1    182992000   289390   3198600    8740          17220   106670
# 2    185771000   301510   3450700    8530          17550   110860
# 3    188483000   316970   3792500    8640          17650   116470
# 4    191141000   364220   4200400    9360          21420   130390
# 5    193526000   387390   4352000    9960          23410   138690
# 6    195576000   430180   4793300   11040          25820   157990
# 7    197457000   499930   5403500   12240          27620   202910
# 8    199399000   595010   6125200   13800          31670   262840
# 9    201385000   661870   6749000   14760          37170   298850
# 10   203235298   738820   7359200   16000          37990   349860
# 11   206212000   816500   7771700   17780          42260   387700
# 12   208230000   834900   7413900   18670          46850   376290
# 13   209851000   875910   7842200   19640          51400   384220
# 14   211392000   974720   9278700   20710          55400   442400
# 15   213124000  1039710  10252700   20510          56090   470500
# 16   214659000  1004210  10345500   18780          57080   427810
# 17   216332000  1029580   9955000   19120          63500   412610
# 18   218059000  1085550  10123400   19560          67610   426930
# 19   220099000  1208030  11041500   21460          76390   480700
# 20   225349264  1344520  12063700   23040          82990   565840
# 21   229146000  1361820  12061900   22520          82500   592910
# 22   231534000  1322390  11652000   21010          78770   553130
# 23   233981000  1258090  10850500   19310          78920   506570
# 24   236158000  1273280  10608500   18690          84230   485010
# 25   238740000  1328800  11102600   18980          88670   497870
# 26   240132887  1489169  11722700   20613          91459   542775
# 27   242282918  1483999  12024700   20096          91110   517704
# 28   245807000  1566220  12356900   20680          92490   542970
# 29   248239000  1646040  12605400   21500          94500   578330
# 30   248709873  1820130  12655500   23440         102560   639270
# 31   252177000  1911770  12961100   24700         106590   687730
# 32   255082000  1932270  12505900   23760         109060   672480
# 33   257908000  1926020  12218800   24530         106010   659870
# 34   260341000  1857670  12131900   23330         102220   618950
# 35   262755000  1798790  12063900   21610          97470   580510
# 36   265228572  1688540  11805300   19650          96250   535590
# 37   267637000  1634770  11558175   18208          96153   498534
# 38   270296000  1531044  10944590   16914          93103   446625
# 39   272690813  1426044  10208334   15522          89411   409371
# 40   281421906  1425486  10182586   15586          90178   408016
# 41   285317559  1439480  10437480   16037          90863   423557
# 42   287973924  1423677  10455277   16229          95235   420806
# 43   290690788  1383676  10442862   16528          93883   414235
# 44   293656842  1360088  10319386   16148          95089   401470
# 45   296507061  1390745  10174754   16740          94347   417438
# 46   299398484  1418043   9983568   17030          92757   447403
# 47   301621157  1408337   9843481   16929          90427   445125
# 48   304374846  1392628   9767915   16442          90479   443574
# 49   307006550  1325896   9337060   15399          89241   408742
# 50   309330219  1251248   9112625   14772          85593   369089
# 51   311587816  1206031   9052743   14661          84175   354772
# 52   313873685  1217067   9001992   14866          85141   355051
# 53   316497531  1199684   8650761   14319          82109   345095
# 54   318857056  1197987   8277829   14249          84041   325802
#
#     Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0               154320    912100        1855400         328200
# 1               156760    949600        1913000         336000
# 2               164570    994300        2089600         366800
# 3               174210   1086400        2297800         408300
# 4               203050   1213200        2514400         472800
# 5               215330   1282500        2572600         496900
# 6               235330   1410100        2822000         561200
# 7               257160   1632100        3111600         659800
# 8               286700   1858900        3482700         783600
# 9               311090   1981900        3888600         878500
# 10              334970   2205000        4225800         928400
# 11              368760   2399300        4424200         948200
# 12              393090   2375500        4151200         887200
# 13              420650   2565500        4347900         928800
# 14              456210   3039200        5262500         977100
# 15              492620   3265300        5977700        1009600
# 16              500530   3108700        6270800         966000
# 17              534350   3071500        5905700         977700
# 18              571460   3128300        5991000        1004100
# 19              629480   3327700        6601000        1112800
# 20              672650   3795200        7136900        1131700
# 21              663900   3779700        7194400        1087800
# 22              669480   3447100        7142500        1062400
# 23              653290   3129900        6712800        1007900
# 24              685350   2984400        6591900        1032200
# 25              723250   3073300        6926400        1102900
# 26              834322   3241410        7257153        1224137
# 27              855088   3236184        7499900        1288674
# 28              910090   3218100        7705900        1432900
# 29              951710   3168200        7872400        1564800
# 30             1054860   3073900        7945700        1635900
# 31             1092740   3157200        8142200        1661700
# 32             1126970   2979900        7915200        1610800
# 33             1135610   2834800        7820900        1563100
# 34             1113180   2712800        7879800        1539300
# 35             1099210   2593800        7997700        1472400
# 36             1037050   2506400        7904700        1394200
# 37             1023201   2460526        7743760        1354189
# 38              974402   2329950        7373886        1240754
# 39              911740   2100739        6955520        1152075
# 40              911706   2050992        6971590        1160002
# 41              909023   2116531        7092267        1228391
# 42              891407   2151252        7057370        1246646
# 43              859030   2154834        7026802        1261226
# 44              847381   2144446        6937089        1237851
# 45              862220   2155448        6783447        1235859
# 46              860853   2183746        6607013        1192809
# 47              855856   2176140        6568572        1095769
# 48              842134   2228474        6588046         958629
# 49              812514   2203313        6338095         795652
# 50              781844   2168457        6204601         739565
# 51              752423   2185140        6151095         716508
# 52              762009   2109932        6168874         723186
# 53              726575   1931835        6018632         700294
# 54              741291   1729806        5858496         689527

# %%
del crime['Total']
crime.head()
# Out:
#    Population  Violent  Property  Murder  Forcible_Rape  Robbery  \
# 0   179323175   288460   3095700    9110          17190   107840
# 1   182992000   289390   3198600    8740          17220   106670
# 2   185771000   301510   3450700    8530          17550   110860
# 3   188483000   316970   3792500    8640          17650   116470
# 4   191141000   364220   4200400    9360          21420   130390
#
#    Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0              154320    912100        1855400         328200
# 1              156760    949600        1913000         336000
# 2              164570    994300        2089600         366800
# 3              174210   1086400        2297800         408300
# 4              203050   1213200        2514400         472800

# %% [markdown]
# ### Step 8. Group the year by decades and sum the values
#
# #### Pay attention to the Population column number, summing this column is a mistake

# %%
# Uses resample to get the max value only for the "Population" column
population = crime['Population'].resample('10AS').max()

# Updating the "Population" column
crimes['Population'] = population
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-3989d6bf55e8> in <module>
#       1 # Uses resample to get the max value only for the "Population" column
# ----> 2 population = crime['Population'].resample('10AS').max()
#       3
#       4 # Updating the "Population" column
#       5 crimes['Population'] = population
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level)
#    8102
#    8103         axis = self._get_axis_number(axis)
# -> 8104         return resample(
#    8105             self,
#    8106             freq=rule,
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#    1268     """
#    1269     tg = TimeGrouper(**kwds)
# -> 1270     return tg._get_resampler(obj, kind=kind)
#    1271
#    1272
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
#    1401             return TimedeltaIndexResampler(obj, groupby=self, axis=self.axis)
#    1402
# -> 1403         raise TypeError(
#    1404             "Only valid with DatetimeIndex, "
#    1405             "TimedeltaIndex or PeriodIndex, "
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'

# %%
crimes
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-82ca47d267f5> in <module>
# ----> 1 crimes
#
# NameError: name 'crimes' is not defined

# %%
# To learn more about .resample (https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.resample.html)
# To learn more about Offset Aliases (http://pandas.pydata.org/pandas-docs/stable/timeseries.html#offset-aliases)

# Uses resample to sum each decade
crimes = crime.resample('10AS').sum()

crimes
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-44b12a53c78a> in <module>
#       3
#       4 # Uses resample to sum each decade
# ----> 5 crimes = crime.resample('10AS').sum()
#       6
#       7 crimes
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\generic.py in resample(self, rule, axis, closed, label, convention, kind, loffset, base, on, level)
#    8102
#    8103         axis = self._get_axis_number(axis)
# -> 8104         return resample(
#    8105             self,
#    8106             freq=rule,
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\resample.py in resample(obj, kind, **kwds)
#    1268     """
#    1269     tg = TimeGrouper(**kwds)
# -> 1270     return tg._get_resampler(obj, kind=kind)
#    1271
#    1272
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\resample.py in _get_resampler(self, obj, kind)
#    1401             return TimedeltaIndexResampler(obj, groupby=self, axis=self.axis)
#    1402
# -> 1403         raise TypeError(
#    1404             "Only valid with DatetimeIndex, "
#    1405             "TimedeltaIndex or PeriodIndex, "
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'RangeIndex'

# %% [markdown]
# ### Step 9. What is the most dangerous decade to live in the US?

# %%
# apparently the 90s was a pretty dangerous time in the US
crimes.idxmax(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-0024227de8ce> in <module>
#       1 # apparently the 90s was a pretty dangerous time in the US
# ----> 2 crimes.idxmax(0)
#
# NameError: name 'crimes' is not defined

# %%
crime.head(5)
# Out:
#    Population  Violent  Property  Murder  Forcible_Rape  Robbery  \
# 0   179323175   288460   3095700    9110          17190   107840
# 1   182992000   289390   3198600    8740          17220   106670
# 2   185771000   301510   3450700    8530          17550   110860
# 3   188483000   316970   3792500    8640          17650   116470
# 4   191141000   364220   4200400    9360          21420   130390
#
#    Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0              154320    912100        1855400         328200
# 1              156760    949600        1913000         336000
# 2              164570    994300        2089600         366800
# 3              174210   1086400        2297800         408300
# 4              203050   1213200        2514400         472800

# %%
df = crime.drop("Population", axis=1)
df.plot()
# Out:
# <AxesSubplot:>
